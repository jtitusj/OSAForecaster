# %% [markdown]
# # OSA Computation
#
# In this notebook, we explore how the availability KPI is computed.

# %%
import sys

sys.path.append('../')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from scripts.compute_osa import compute_osa

# %% [markdown]
# ## Load Data

# %%
filepath = '../data/source/2021 NAI MT & RMT OSA Data (GMA All SKUs).xlsx'
df = pd.read_excel(filepath)
df.head()
# Out:
#    YEAR MONTH    WEEK AREA GROUP    ACCOUNT  \
# 0  2021   JAN  Week 1  GMA  MT 1   LANDMARK
# 1  2021   JAN  Week 1  GMA  MT 1   LANDMARK
# 2  2021   JAN  Week 1  GMA  MT 1   LANDMARK
# 3  2021   JAN  Week 1  GMA  MT 1  ROBINSONS
# 4  2021   JAN  Week 1  GMA  MT 1  ROBINSONS
#
#                                 OUTLET Amihan White Vinegar 1L (68)  \
# 0              LANDMARK ALABANG (4341)                           NR
# 1                 LANDMARK MAKATI (53)                           NR
# 2                LANDMARK TRINOMA (54)                           NR
# 3      JAYNITHS SUPERMART PASIG (3368)                           NR
# 4  JAYNITHS SUPERMART SAN MATEO (3373)                           NR
#
#   Amihan White Vinegar 2L (69) Amihan White Vinegar 4L (70)  ...  \
# 0                           NR                           NR  ...
# 1                           NR                           NR  ...
# 2                           NR                           NR  ...
# ...

# %% [markdown]
# ## Compute OSA per Outlet

# %%
df_osa = compute_osa(df)
df_osa.head()
# Out:
#    YEAR MONTH    WEEK AREA GROUP    ACCOUNT  \
# 0  2021   JAN  Week 1  GMA  MT 1   LANDMARK
# 1  2021   JAN  Week 1  GMA  MT 1   LANDMARK
# 2  2021   JAN  Week 1  GMA  MT 1   LANDMARK
# 3  2021   JAN  Week 1  GMA  MT 1  ROBINSONS
# 4  2021   JAN  Week 1  GMA  MT 1  ROBINSONS
#
#                                 OUTLET       OSA
# 0              LANDMARK ALABANG (4341)  0.787037
# 1                 LANDMARK MAKATI (53)  0.835165
# 2                LANDMARK TRINOMA (54)  0.923077
# 3      JAYNITHS SUPERMART PASIG (3368)  0.955665
# 4  JAYNITHS SUPERMART SAN MATEO (3373)  0.902381
