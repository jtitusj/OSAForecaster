# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = '../data/source/2019-2021 NAI MT & RMT Offtake Data (GMA).xlsx'
df = pd.read_excel(filepath)
df.head()
# Out:
#      YEAR MONTH Week of transaction_date AREA GROUP ACCOUNT/DISTRIBUTOR  \
# 0  2019.0   JAN                   Week 1  GMA  MT 1            LANDMARK
# 1  2019.0   JAN                   Week 1  GMA  MT 1            LANDMARK
# 2  2019.0   JAN                   Week 1  GMA  MT 1            LANDMARK
# 3  2019.0   JAN                   Week 1  GMA  MT 5            PUREGOLD
# 4  2019.0   JAN                   Week 1  GMA  MT 5            PUREGOLD
#
#                              OUTLET NAME Datu Puti Soy Sauce 1L PET (78)  \
# 0                LANDMARK ALABANG (4341)                            7.58
# 1                   LANDMARK MAKATI (53)                              14
# 2                  LANDMARK TRINOMA (54)                              11
# 3    GROCER E SUPERMART - PANORAMA (266)                            0.42
# 4  GROCER E SUPERMART - STA. ELENA (265)                           10.92
#
#   Datu Puti Soy Sauce 200Ml (74) Datu Puti White Vinegar 1L (60)  \
# ...
